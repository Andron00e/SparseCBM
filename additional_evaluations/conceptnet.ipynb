# %%
import open_clip
import clip
from torchvision.datasets import CIFAR10, CIFAR100, ImageNet
from open_clip import tokenizer
import torch
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import os
from sentence_transformers import SentenceTransformer
import requests
import json
import math
import random
from tqdm import tqdm
import nltk
nltk.download("punkt")
from nltk.tokenize import WordPunctTokenizer
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
LABEL_FILES = {"cifar10":"data/cifar10_classes.txt",
               "cifar100": "data/cifar100_classes.txt",
               "cub": "data/cub_classes.txt",
               "imagenet": "data/imagenet_classes.txt"}
LIMIT = 200
RELATIONS = ["HasA", "IsA", "PartOf", "HasProperty", "MadeOf", "AtLocation"]

CLASS_SIM_CUTOFF = 0.85
OTHER_SIM_CUTOFF = 0.9
MAX_LEN = 30
PRINT_PROB = 0.2

dataset = ["cifar10", "cifar100", "cub", "imagenet"]
save_name = ["data/conceptnet_{}_filtered_new.txt".format(data) for data in dataset]

# %%
def get_init_conceptnet(classes, limit=200, relations=["HasA", "IsA", "PartOf", "HasProperty", "MadeOf", "AtLocation"]):
    concepts = set()

    for cls in tqdm(classes):
        words = cls.replace(',', '').split(' ')
        for word in words:
            obj = requests.get('http://api.conceptnet.io/c/en/{}?limit={}'.format(word, limit)).json()
            obj.keys()
            for dicti in obj['edges']:
                rel = dicti['rel']['label']
                try:
                    if dicti['start']['language'] != 'en' or dicti['end']['language'] != 'en':
                        continue
                except(KeyError):
                    continue

                if rel in relations:
                    if rel in ["IsA"]:
                        concepts.add(dicti['end']['label'])
                    else:
                        concepts.add(dicti['start']['label'])
                        concepts.add(dicti['end']['label'])
    return concepts

# %%
def _clip_dot_prods(list1, list2, device="cuda", clip_name="ViT-B/16", batch_size=500):
    "Returns: numpy array with dot products"
    clip_model, _ = clip.load(clip_name, device=device)
    text1 = clip.tokenize(list1).to(device)
    text2 = clip.tokenize(list2).to(device)

    features1 = []
    with torch.no_grad():
        for i in range(math.ceil(len(text1)/batch_size)):
            features1.append(clip_model.encode_text(text1[batch_size*i:batch_size*(i+1)]))
        features1 = torch.cat(features1, dim=0)
        features1 /= features1.norm(dim=1, keepdim=True)

    features2 = []
    with torch.no_grad():
        for i in range(math.ceil(len(text2)/batch_size)):
            features2.append(clip_model.encode_text(text2[batch_size*i:batch_size*(i+1)]))
        features2 = torch.cat(features2, dim=0)
        features2 /= features2.norm(dim=1, keepdim=True)

    dot_prods = features1 @ features2.T
    return dot_prods.cpu().numpy()

# %%
def filter_too_similar_to_cls(concepts, classes, sim_cutoff, device="cuda", print_prob=0):
    #first check simple text matches
    print(len(concepts))
    concepts = list(concepts)
    concepts = sorted(concepts)

    for cls in classes:
        for prefix in ["", "a ", "A ", "an ", "An ", "the ", "The "]:
            try:
                concepts.remove(prefix+cls)
                if random.random()<print_prob:
                    print("Class:{} - Deleting {}".format(cls, prefix+cls))
            except(ValueError):
                pass
        try:
            concepts.remove(cls.upper())
        except(ValueError):
            pass
        try:
            concepts.remove(cls[0].upper()+cls[1:])
        except(ValueError):
            pass
    print(len(concepts))

    mpnet_model = SentenceTransformer('all-mpnet-base-v2')
    class_features_m = mpnet_model.encode(classes)
    concept_features_m = mpnet_model.encode(concepts)
    dot_prods_m = class_features_m @ concept_features_m.T
    dot_prods_c = _clip_dot_prods(classes, concepts)
    #weighted since mpnet has highger variance
    dot_prods = (dot_prods_m + 3*dot_prods_c)/4

    to_delete = []
    for i in range(len(classes)):
        for j in range(len(concepts)):
            prod = dot_prods[i,j]
            if prod >= sim_cutoff and i!=j:
                if j not in to_delete:
                    to_delete.append(j)
                    if random.random()<print_prob:
                        print("Class:{} - Concept:{}, sim:{:.3f} - Deleting {}".format(classes[i], concepts[j], dot_prods[i,j], concepts[j]))
                        print("".format(concepts[j]))

    to_delete = sorted(to_delete)[::-1]

    for item in to_delete:
        concepts.pop(item)
    print(len(concepts))
    return concepts

# %%
def filter_too_similar(concepts, sim_cutoff, device="cuda", print_prob=0):

    mpnet_model = SentenceTransformer('all-mpnet-base-v2')
    concept_features = mpnet_model.encode(concepts)

    dot_prods_m = concept_features @ concept_features.T
    dot_prods_c = _clip_dot_prods(concepts, concepts)

    dot_prods = (dot_prods_m + 3*dot_prods_c)/4

    to_delete = []
    for i in range(len(concepts)):
        for j in range(len(concepts)):
            prod = dot_prods[i,j]
            if prod >= sim_cutoff and i!=j:
                if i not in to_delete and j not in to_delete:
                    to_print = random.random() < print_prob
                    #Deletes the concept with lower average similarity to other concepts - idea is to keep more general concepts
                    if np.sum(dot_prods[i]) < np.sum(dot_prods[j]):
                        to_delete.append(i)
                        if to_print:
                            print("{} - {} , sim:{:.4f} - Deleting {}".format(concepts[i], concepts[j], dot_prods[i,j], concepts[i]))
                    else:
                        to_delete.append(j)
                        if to_print:
                            print("{} - {} , sim:{:.4f} - Deleting {}".format(concepts[i], concepts[j], dot_prods[i,j], concepts[j]))

    to_delete = sorted(to_delete)[::-1]
    for item in to_delete:
        concepts.pop(item)
    print(len(concepts))
    return concepts

# %%
def remove_too_long(concepts, max_len, print_prob=0):
    new_concepts = []
    for concept in concepts:
        if len(concept) <= max_len:
            new_concepts.append(concept)
        else:
            if random.random()<print_prob:
                print(len(concept), concept)
    print(len(concepts), len(new_concepts))
    return new_concepts

# %%
cls_cifar10 = "data/cifar10_classes.txt"
cls_cifar100 = "data/cifar100_classes.txt"
cls_imagenet = "data/imagenet_classes.txt"
cls_cub = "data/cub_classes.txt"

with open(cls_cifar10, 'r') as f:
    classes_cifar10 = f.read().split('\n')

with open(cls_cifar100, 'r') as f:
    classes_cifar100 = f.read().split('\n')

with open(cls_imagenet, 'r') as f:
    classes_imagenet = f.read().split('\n')

with open(cls_cub, 'r') as f:
    classes_cub = f.read().split('\n')

classes = classes_cifar10 + classes_cifar100 + classes_imagenet + classes_cub

unique = []
for item in classes:
  if item not in unique:
    unique.append(item)

classes = unique

classes = [item.lower() for item in classes]

save_classes = "data/all_classes.txt"
with open(save_classes, "w") as f:
  for item in classes:
    f.write(item + "\n")

# %%
concepts = get_init_conceptnet(classes, LIMIT, RELATIONS)
concepts = remove_too_long(concepts, MAX_LEN, PRINT_PROB)
concepts = filter_too_similar_to_cls(concepts, classes, CLASS_SIM_CUTOFF, print_prob=PRINT_PROB)
concepts = filter_too_similar(concepts, OTHER_SIM_CUTOFF, print_prob=PRINT_PROB)
# Out:
# 100%|██████████| 1000/1000 [15:55<00:00,  1.05it/s]
# 38 One word that is frequently misspelled
# 33 the accent on the second syllable
# 34 a wilderness area away from people
# 33 a fast pacedand hard hitting game
# 32 dirt tracked in from the outside
# 38 naturally occurring tangible substance
# 31 a Discovery Channel documentary
# 31 single reed woodwind instrument
# 31 less cramped than an automobile
# 31 cooked to make them more edible
# 6780 6712
# 6712
# Class:goldfish - Deleting goldfish
# Class:bald eagle - Deleting a bald eagle
# Class:harvestman - Deleting harvestman
# Class:scorpion - Deleting scorpion
# Class:centipede - Deleting centipede
# Class:tusker - Deleting tusker
# Class:koala - Deleting a koala
# Class:flatworm - Deleting flatworm
# Class:spoonbill - Deleting spoonbill
# Class:albatross - Deleting albatross
# Class:lion - Deleting lion
# Class:meerkat - Deleting meerkat
# Class:hamster - Deleting hamster
# Class:hamster - Deleting a hamster
# Class:beaver - Deleting beaver
# Class:beaver - Deleting a beaver
# Class:gorilla - Deleting gorilla
# Class:baboon - Deleting baboon
# Class:macaque - Deleting macaque
# Class:marmoset - Deleting marmoset
# Class:marmoset - Deleting a marmoset
# Class:accordion - Deleting an accordion
# Class:airliner - Deleting airliner
# Class:altar - Deleting altar
# Class:trash can - Deleting a trash can
# Class:barber chair - Deleting barber chair
# Class:barn - Deleting barn
# Class:barn - Deleting the barn
# Class:baseball - Deleting A baseball
# Class:broom - Deleting broom
# Class:carousel - Deleting carousel
# Class:coffee mug - Deleting a coffee mug
# Class:diaper - Deleting diaper
# Class:dome - Deleting dome
# Class:drum - Deleting drum
# Class:envelope - Deleting an envelope
# Class:fur coat - Deleting fur coat
# Class:hammer - Deleting hammer
# Class:hamper - Deleting hamper
# Class:hamper - Deleting the hamper
# Class:harp - Deleting harp
# Class:holster - Deleting a holster
# Class:knot - Deleting knot
# Class:lampshade - Deleting lampshade
# Class:library - Deleting a library
# Class:library - Deleting A library
# Class:library - Deleting the library
# Class:lifeboat - Deleting a lifeboat
# Class:lighter - Deleting a lighter
# Class:lotion - Deleting The lotion
# Class:tights - Deleting tights
# Class:megalith - Deleting megalith
# Class:microphone - Deleting microphone
# Class:monastery - Deleting monastery
# Class:monitor - Deleting monitor
# Class:mosque - Deleting mosque
# Class:tent - Deleting a tent
# Class:necklace - Deleting a necklace
# Class:obelisk - Deleting an obelisk
# Class:palace - Deleting a palace
# Class:parachute - Deleting parachute
# Class:pencil case - Deleting a pencil case
# Class:photocopier - Deleting photocopier
# Class:plectrum - Deleting a plectrum
# Class:projector - Deleting projector
# Class:purse - Deleting a purse
# Class:radiator - Deleting radiator
# Class:revolver - Deleting revolver
# Class:revolver - Deleting A revolver
# Class:rotisserie - Deleting a rotisserie
# Class:eraser - Deleting An eraser
# Class:safe - Deleting a safe
# Class:scabbard - Deleting scabbard
# Class:scoreboard - Deleting a scoreboard
# Class:shower curtain - Deleting a shower curtain
# Class:snorkel - Deleting snorkel
# Class:space shuttle - Deleting space shuttle
# Class:spatula - Deleting spatula
# Class:stage - Deleting stage
# Class:stage - Deleting a stage
# Class:stethoscope - Deleting stethoscope
# Class:couch - Deleting the couch
# Class:swing - Deleting swing
# Class:television - Deleting a television
# Class:tripod - Deleting A tripod
# Class:unicycle - Deleting a unicycle
# Class:vestment - Deleting vestment
# Class:violin - Deleting A violin
# Class:volleyball - Deleting a volleyball
# Class:wardrobe - Deleting a wardrobe
# Class:sink - Deleting a sink
# Class:menu - Deleting a menu
# Class:plate - Deleting a plate
# Class:bagel - Deleting a bagel
# Class:artichoke - Deleting artichoke
# Class:strawberry - Deleting strawberry
# Class:orange - Deleting orange
# Class:meatloaf - Deleting meatloaf
# Class:pizza - Deleting a pizza
# Class:burrito - Deleting burrito
# Class:mountain - Deleting a mountain
# Class:valley - Deleting valley
# Class:volcano - Deleting volcano
# Class:agaric - Deleting agaric
# 6108
# Downloading (…)a8e1d/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)b20bca8e1d/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)0bca8e1d/config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)e1d/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading (…)a8e1d/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading (…)8e1d/train_script.py:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading (…)b20bca8e1d/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)bca8e1d/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# 100%|████████████████████████████████████████| 335M/335M [00:02<00:00, 161MiB/s]
# Class:hammerhead shark - Concept:hammerhead, sim:0.887 - Deleting hammerhead
#
# Class:kite (bird of prey) - Concept:kite, sim:0.880 - Deleting kite
#
# Class:bald eagle - Concept:eagle, sim:0.880 - Deleting eagle
#
# Class:tree frog - Concept:A frog, sim:0.881 - Deleting A frog
#
# Class:tree frog - Concept:a frog, sim:0.881 - Deleting a frog
#
# Class:boa constrictor - Concept:constrictor, sim:0.880 - Deleting constrictor
#
# Class:Indian cobra - Concept:cobra, sim:0.875 - Deleting cobra
#
# Class:prairie grouse - Concept:grouse, sim:0.863 - Deleting grouse
#
# Class:duck - Concept:sea duck, sim:0.888 - Deleting sea duck
#
# Class:sea anemone - Concept:anemone, sim:0.869 - Deleting anemone
#
# Class:great egret - Concept:egret, sim:0.861 - Deleting egret
#
# Class:crane bird - Concept:a bird, sim:0.855 - Deleting a bird
#
# Class:ruddy turnstone - Concept:turnstone, sim:0.890 - Deleting turnstone
#
# Class:red fox - Concept:The fox, sim:0.862 - Deleting The fox
#
# Class:cricket insect - Concept:An insect, sim:0.871 - Deleting An insect
#
# Class:cricket insect - Concept:insect, sim:0.879 - Deleting insect
#
# Class:monarch butterfly - Concept:butterfly, sim:0.855 - Deleting butterfly
#
# Class:wild boar - Concept:a boar, sim:0.901 - Deleting a boar
#
# Class:arabian camel - Concept:a camel, sim:0.876 - Deleting a camel
#
# Class:weasel - Concept:a weasel trap, sim:0.859 - Deleting a weasel trap
#
# Class:Asian elephant - Concept:An elephant, sim:0.897 - Deleting An elephant
#
# Class:Asian elephant - Concept:an elephant, sim:0.897 - Deleting an elephant
#
# Class:silver salmon - Concept:Salmon, sim:0.883 - Deleting Salmon
#
# Class:acoustic guitar - Concept:guitar, sim:0.892 - Deleting guitar
#
# Class:airliner - Concept:aircraft, sim:0.890 - Deleting aircraft
#
# Class:analog clock - Concept:clock, sim:0.856 - Deleting clock
#
# Class:trash can - Concept:a garbage can, sim:0.937 - Deleting a garbage can
#
# Class:trash can - Concept:a garbage waste, sim:0.853 - Deleting a garbage waste
#
# Class:trash can - Concept:a trash bin, sim:0.932 - Deleting a trash bin
#
# Class:bakery - Concept:pastry, sim:0.852 - Deleting pastry
#
# Class:baseball - Concept:a baseball team, sim:0.868 - Deleting a baseball team
#
# Class:baseball - Concept:football, sim:0.863 - Deleting football
#
# Class:basketball - Concept:a basketball game, sim:0.911 - Deleting a basketball game
#
# Class:bathtub - Concept:tub, sim:0.896 - Deleting tub
#
# Class:station wagon - Concept:wagon, sim:0.874 - Deleting wagon
#
# Class:beer bottle - Concept:bottle, sim:0.911 - Deleting bottle
#
# Class:beer glass - Concept:Glass, sim:0.861 - Deleting Glass
#
# Class:ring binder - Concept:a binder, sim:0.868 - Deleting a binder
#
# Class:bookcase - Concept:A shelf, sim:0.854 - Deleting A shelf
#
# Class:bottle cap - Concept:bottlecap, sim:0.951 - Deleting bottlecap
#
# Class:car wheel - Concept:Wheel, sim:0.916 - Deleting Wheel
#
# Class:mobile phone - Concept:phone, sim:0.925 - Deleting phone
#
# Class:coffee mug - Concept:a coffee cup, sim:0.928 - Deleting a coffee cup
#
# Class:spiral or coil - Concept:a coil, sim:0.890 - Deleting a coil
#
# Class:spiral or coil - Concept:spiral, sim:0.868 - Deleting spiral
#
# Class:computer keyboard - Concept:keyboard, sim:0.916 - Deleting keyboard
#
# Class:candy store - Concept:Candy, sim:0.887 - Deleting Candy
#
# Class:cowboy hat - Concept:hat, sim:0.852 - Deleting hat
#
# Class:desk - Concept:your desk, sim:0.899 - Deleting your desk
#
# Class:desktop computer - Concept:computer, sim:0.910 - Deleting computer
#
# Class:desktop computer - Concept:computer monitor, sim:0.865 - Deleting computer monitor
#
# Class:dining table - Concept:a dinning room, sim:0.856 - Deleting a dinning room
#
# Class:dining table - Concept:dining room, sim:0.890 - Deleting dining room
#
# Class:dog sled - Concept:sled, sim:0.874 - Deleting sled
#
# Class:fire truck - Concept:truck, sim:0.860 - Deleting truck
#
# Class:garbage truck - Concept:A truck, sim:0.865 - Deleting A truck
#
# Class:garbage truck - Concept:a truck, sim:0.865 - Deleting a truck
#
# Class:grand piano - Concept:piano, sim:0.850 - Deleting piano
#
# Class:radiator grille - Concept:grille, sim:0.877 - Deleting grille
#
# Class:hoop skirt - Concept:skirt, sim:0.858 - Deleting skirt
#
# Class:gymnastic horizontal bar - Concept:horizontal bar, sim:0.858 - Deleting horizontal bar
#
# Class:lipstick - Concept:makeup, sim:0.856 - Deleting makeup
#
# Class:music speaker - Concept:speakers, sim:0.862 - Deleting speakers
#
# Class:milk can - Concept:milk, sim:0.863 - Deleting milk
#
# Class:pipe organ - Concept:an organ, sim:0.851 - Deleting an organ
#
# Class:product packet / packaging - Concept:package, sim:0.858 - Deleting package
#
# Class:park bench - Concept:a bench, sim:0.902 - Deleting a bench
#
# Class:park bench - Concept:a bench to sit on, sim:0.855 - Deleting a bench to sit on
#
# Class:railroad car - Concept:railroad, sim:0.884 - Deleting railroad
#
# Class:pickup truck - Concept:a pickup, sim:0.872 - Deleting a pickup
#
# Class:pill bottle - Concept:pill, sim:0.864 - Deleting pill
#
# Class:pirate ship - Concept:pirate, sim:0.888 - Deleting pirate
#
# Class:plastic bag - Concept:a plastic, sim:0.856 - Deleting a plastic
#
# Class:plastic bag - Concept:dust bag, sim:0.853 - Deleting dust bag
#
# Class:soda bottle - Concept:Soda, sim:0.854 - Deleting Soda
#
# Class:soda bottle - Concept:a soda, sim:0.859 - Deleting a soda
#
# Class:power drill - Concept:a drill, sim:0.896 - Deleting a drill
#
# Class:prison - Concept:prisoners, sim:0.883 - Deleting prisoners
#
# Class:hockey puck - Concept:a puck, sim:0.914 - Deleting a puck
#
# Class:radio - Concept:radio frequency, sim:0.882 - Deleting radio frequency
#
# Class:radio - Concept:radio receiver, sim:0.871 - Deleting radio receiver
#
# Class:refrigerator - Concept: the fridge, sim:0.904 - Deleting  the fridge
#
# Class:sneaker - Concept:a shoe, sim:0.851 - Deleting a shoe
#
# Class:sneaker - Concept:shoe, sim:0.890 - Deleting shoe
#
# Class:sneaker - Concept:shoes, sim:0.877 - Deleting shoes
#
# Class:shopping basket - Concept:a basket, sim:0.860 - Deleting a basket
#
# Class:sock - Concept:a lost sock, sim:0.881 - Deleting a lost sock
#
# Class:sock - Concept:dirty socks, sim:0.865 - Deleting dirty socks
#
# Class:sock - Concept:socks, sim:0.931 - Deleting socks
#
# Class:space shuttle - Concept:shuttle, sim:0.901 - Deleting shuttle
#
# Class:stage - Concept:theater stage, sim:0.899 - Deleting theater stage
#
# Class:stove - Concept:oven, sim:0.850 - Deleting oven
#
# Class:submarine - Concept:submarines, sim:0.860 - Deleting submarines
#
# Class:sunglasses - Concept:"sunglasses", sim:0.932 - Deleting "sunglasses"
#
# Class:sweatshirt - Concept:a sweater, sim:0.862 - Deleting a sweater
#
# Class:table lamp - Concept:lamp, sim:0.864 - Deleting lamp
#
# Class:television - Concept:television programs, sim:0.887 - Deleting television programs
#
# Class:front curtain - Concept:a stage curtain, sim:0.871 - Deleting a stage curtain
#
# Class:tile roof - Concept:roof tiles, sim:0.923 - Deleting roof tiles
#
# Class:toy store - Concept:pet store, sim:0.859 - Deleting pet store
#
# Class:velvet fabric - Concept:Velvet, sim:0.895 - Deleting Velvet
#
# Class:violin - Concept:string instrument, sim:0.869 - Deleting string instrument
#
# Class:wallet - Concept:your wallet, sim:0.913 - Deleting your wallet
#
# Class:wardrobe - Concept:a clothes, sim:0.868 - Deleting a clothes
#
# Class:hair wig - Concept:a hair, sim:0.860 - Deleting a hair
#
# Class:sailboat - Concept:sailing vessel, sim:0.895 - Deleting sailing vessel
#
# Class:butternut squash - Concept:squash, sim:0.851 - Deleting squash
#
# Class:mushroom - Concept:mushrooms, sim:0.928 - Deleting mushrooms
#
# Class:strawberry - Concept:Ripe strawberries, sim:0.859 - Deleting Ripe strawberries
#
# Class:banana - Concept:banana peel, sim:0.881 - Deleting banana peel
#
# Class:chocolate syrup - Concept:Syrup, sim:0.872 - Deleting Syrup
#
# Class:pizza - Concept:pizza store, sim:0.878 - Deleting pizza store
#
# Class:mountain - Concept:a mountainous state, sim:0.857 - Deleting a mountainous state
#
# Class:mountain - Concept:mountain peak, sim:0.936 - Deleting mountain peak
#
# Class:mountain - Concept:the mountains, sim:0.909 - Deleting the mountains
#
# Class:coral reef - Concept:coral, sim:0.888 - Deleting coral
#
# Class:scuba diver - Concept:a diver, sim:0.883 - Deleting a diver
#
# 5509
# A bay - a bay , sim:0.9995 - Deleting a bay
# A bay - bay , sim:0.9128 - Deleting bay
# A brain - brain , sim:0.9106 - Deleting brain
# A brain - the brain , sim:0.9130 - Deleting the brain
# A container - container , sim:0.9537 - Deleting container
# A disk - disk , sim:0.9357 - Deleting A disk
# A handle - The handle , sim:0.9157 - Deleting A handle
# A horse - horse , sim:0.9558 - Deleting horse
# A king - a king , sim:1.0000 - Deleting a king
# A leg - a leg , sim:1.0010 - Deleting a leg
# A living room - a living room , sim:1.0010 - Deleting a living room
# A living room - a livingroom , sim:0.9790 - Deleting a livingroom
# A living room - living room , sim:0.9597 - Deleting living room
# A pencil - a pen , sim:0.9158 - Deleting A pencil
# A rhinoceros - rhinoceros , sim:0.9577 - Deleting A rhinoceros
# A tree - a tree , sim:1.0000 - Deleting a tree
# A wall - a wall space , sim:0.9008 - Deleting a wall space
# A wall - wall , sim:0.9151 - Deleting wall
# A wave - waves , sim:0.9237 - Deleting waves
# A window - the window , sim:0.9484 - Deleting the window
# All mammals - Mammals , sim:0.9186 - Deleting All mammals
# An eye - the eye , sim:0.9207 - Deleting An eye
# An index card - an index card , sim:0.9995 - Deleting an index card
# Apples - some apples , sim:0.9296 - Deleting some apples
# British Columbia - Vancouver Island , sim:0.9067 - Deleting Vancouver Island
# Burrow underground - an underground burrow , sim:0.9209 - Deleting Burrow underground
# Butter - butter , sim:1.0000 - Deleting butter
# Carrots - carrots , sim:0.9995 - Deleting carrots
# Cats - cats , sim:0.9995 - Deleting cats
# Colorado - colorado , sim:1.0000 - Deleting colorado
# Fish - food fish , sim:0.9215 - Deleting food fish
# Ink - ink , sim:1.0010 - Deleting ink
# Music - music , sim:1.0000 - Deleting music
# Music - some music , sim:0.9229 - Deleting Music
# North America - north america , sim:1.0000 - Deleting north america
# One of the chemical elements - chemical element , sim:0.9268 - Deleting One of the chemical elements
# Paper - paper , sim:1.0000 - Deleting paper
# Potatoes - potato , sim:0.9346 - Deleting Potatoes
# Rain - rain , sim:0.9990 - Deleting rain
# Red - red , sim:1.0010 - Deleting red
# Santa Clause - santa claus , sim:0.9538 - Deleting Santa Clause
# Snow - snow , sim:1.0010 - Deleting snow
# Some malls - a mall , sim:0.9133 - Deleting Some malls
# The Amazon - the Amazon , sim:0.9995 - Deleting the Amazon
# The Earth - the Earth , sim:1.0010 - Deleting the Earth
# The Earth - the earth , sim:1.0010 - Deleting the earth
# The handle - a handle , sim:0.9157 - Deleting a handle
# The sea - a sea , sim:0.9339 - Deleting The sea
# a California zoo - the San Diego Zoo , sim:0.9049 - Deleting the San Diego Zoo
# a back yard - a kid's back yard , sim:0.9251 - Deleting a kid's back yard
# a back yard - my yard , sim:0.9125 - Deleting my yard
# a bank - bank , sim:0.9509 - Deleting a bank
# a bar - bar , sim:0.9367 - Deleting bar
# a barber comb - a comb , sim:0.9028 - Deleting a barber comb
# a basement - the basement , sim:0.9187 - Deleting a basement
# a beanbag - a beanbag chair , sim:0.9269 - Deleting a beanbag chair
# a blotter - blotter , sim:0.9591 - Deleting blotter
# a body of water - a man made body of water , sim:0.9421 - Deleting a man made body of water
# a bookmark - bookmarks , sim:0.9143 - Deleting bookmarks
# a bug - bugs , sim:0.9118 - Deleting bugs
# a cage at the zoo - a cage in a zoo , sim:0.9739 - Deleting a cage at the zoo
# a cake - a cake in , sim:0.9388 - Deleting a cake in
# a calendar - a calendar book , sim:0.9310 - Deleting a calendar book
# a can - cans , sim:0.9025 - Deleting cans
# a carbonated beverage - carbonated , sim:0.9062 - Deleting a carbonated beverage
# a card catalogue - card catalog , sim:0.9294 - Deleting card catalog
# a carnivore - carnivore , sim:0.9591 - Deleting carnivore
# a carpet - carpet , sim:0.9494 - Deleting carpet
# a ceiling - the ceiling , sim:0.9513 - Deleting the ceiling
# a cellar - the cellar , sim:0.9239 - Deleting a cellar
# a checkbook - checkbook , sim:0.9592 - Deleting checkbook
# a chicken - a male chicken , sim:0.9101 - Deleting a male chicken
# a chicken - chicken , sim:0.9382 - Deleting a chicken
# a church central passage - a church side passage , sim:0.9457 - Deleting a church side passage
# a circus - the circus , sim:0.9625 - Deleting the circus
# a clothes drawer - a drawer , sim:0.9209 - Deleting a clothes drawer
# a cocktail - cocktail , sim:0.9532 - Deleting a cocktail
# a color - a colour , sim:0.9848 - Deleting a colour
# a communication device - a device , sim:0.9069 - Deleting a communication device
# a community - community , sim:0.9363 - Deleting community
# a creature of the sea - a sea animal , sim:0.9303 - Deleting a sea animal
# a curve - curve , sim:0.9569 - Deleting curve
# a delicious meal - a food , sim:0.9015 - Deleting a delicious meal
# a device - an electronic device , sim:0.9468 - Deleting an electronic device
# a dirt hole - a hole , sim:0.9058 - Deleting a dirt hole
# a double reed woodwind - double reed woodwind , sim:0.9707 - Deleting double reed woodwind
# a dryer - the dryer , sim:0.9348 - Deleting the dryer
# a farm - a farm crop , sim:0.9153 - Deleting a farm crop
# a farmhouse - farmhouse , sim:0.9558 - Deleting a farmhouse
# a field - an open field , sim:0.9056 - Deleting a field
# a firearm - a gun , sim:0.9453 - Deleting a firearm
# a fisherman's boat - a fishing boat , sim:0.9559 - Deleting a fisherman's boat
# a floor - floor , sim:0.9335 - Deleting floor
# a floor covering - floor cover , sim:0.9240 - Deleting floor cover
# a food - a food item , sim:0.9457 - Deleting a food
# a form of clothing - a form of female attire , sim:0.9088 - Deleting a form of female attire
# a form of clothing - a garment , sim:0.9116 - Deleting a form of clothing
# a furniture - a furniture item , sim:0.9535 - Deleting a furniture item
# a furniture - furniture , sim:0.9485 - Deleting furniture
# a game on ice - a game people play on ice , sim:0.9342 - Deleting a game people play on ice
# a game on ice - an ice hockey game , sim:0.9024 - Deleting an ice hockey game
# a game people play - a sport people play , sim:0.9060 - Deleting a sport people play
# a garment - an article of clothing , sim:0.9194 - Deleting an article of clothing
# a golf course - golf course , sim:0.9583 - Deleting a golf course
# a good friend - a loyal friend , sim:0.9060 - Deleting a loyal friend
# a green vegetable - a vegetable , sim:0.9108 - Deleting a green vegetable
# a hardware store - a home improvement store , sim:0.9096 - Deleting a hardware store
# a head - someone's head , sim:0.9170 - Deleting a head
# a hotel - a large hotel , sim:0.9425 - Deleting a large hotel
# a kid - a very young child , sim:0.9295 - Deleting a very young child
# a killer - killer , sim:0.9058 - Deleting killer
# a kitchen tool - kitchen tool , sim:0.9715 - Deleting kitchen tool
# a lab - lab , sim:0.9157 - Deleting a lab
# a large wading bird - wading bird , sim:0.9256 - Deleting a large wading bird
# a lifeguard - lifeguards , sim:0.9161 - Deleting lifeguards
# a light meal - a meal , sim:0.9345 - Deleting a light meal
# a lion's belly - a lion's stomach , sim:0.9039 - Deleting a lion's stomach
# a lion's belly - the belly of a lion , sim:0.9502 - Deleting the belly of a lion
# a locker - a school locker , sim:0.9326 - Deleting a school locker
# a lot of books - many, many books , sim:0.9151 - Deleting many, many books
# a machine - a very complex machine , sim:0.9029 - Deleting a very complex machine
# a magazine - magazines , sim:0.9215 - Deleting magazines
# a magnet - magnet , sim:0.9428 - Deleting magnet
# a mall - a shopping mall , sim:0.9582 - Deleting a shopping mall
# a metal - metal , sim:0.9441 - Deleting metal
# a microscope - microscope , sim:0.9597 - Deleting microscope
# a museum - an art museum , sim:0.9531 - Deleting an art museum
# a music instrument - a musical instrument , sim:0.9894 - Deleting a music instrument
# a music shop - a music store , sim:0.9786 - Deleting a music shop
# a musical insrrument - an music intrument , sim:0.9163 - Deleting an music intrument
# a musical string instrument - a string instrument , sim:0.9794 - Deleting a musical string instrument
# a national park - a state park , sim:0.9233 - Deleting a state park
# a neck - neck , sim:0.9311 - Deleting a neck
# a neighborhood - a suburb , sim:0.9017 - Deleting a suburb
# a neural structure - neural structure , sim:0.9614 - Deleting neural structure
# a newspaper - newspaper , sim:0.9609 - Deleting newspaper
# a notepad - a writing pad , sim:0.9097 - Deleting a writing pad
# a package - packages , sim:0.9213 - Deleting packages
# a pad of paper - a sheet of paper , sim:0.9455 - Deleting a pad of paper
# a pantry - the pantry , sim:0.9376 - Deleting a pantry
# a park - the park , sim:0.9538 - Deleting a park
# a part of the human body - a part of your body , sim:0.9352 - Deleting a part of the human body
# a pen - a pencil , sim:0.9158 - Deleting a pencil
# a piece - piece , sim:0.9331 - Deleting piece
# a place - place , sim:0.9307 - Deleting place
# a player - player , sim:0.9383 - Deleting a player
# a potato - potato , sim:0.9440 - Deleting a potato
# a product - product , sim:0.9483 - Deleting product
# a puzzle - puzzle , sim:0.9449 - Deleting puzzle
# a reflection - a reflective surface , sim:0.9066 - Deleting a reflective surface
# a ribbon - ribbon , sim:0.9472 - Deleting ribbon
# a road - a street , sim:0.9096 - Deleting a street
# a road - road , sim:0.9274 - Deleting a road
# a round object - round shape , sim:0.9093 - Deleting round shape
# a seat - seat , sim:0.9251 - Deleting seat
# a sheep - sheep , sim:0.9310 - Deleting a sheep
# a shower - shower , sim:0.9428 - Deleting shower
# a single moon - one moon , sim:0.9281 - Deleting a single moon
# a small rodent - rodent , sim:0.9008 - Deleting a small rodent
# a sporting goods store - sporting goods , sim:0.9082 - Deleting a sporting goods store
# a spring - spring , sim:0.9006 - Deleting spring
# a stadium - stadium , sim:0.9514 - Deleting a stadium
# a state of matter - state of matter , sim:0.9722 - Deleting state of matter
# a station - station , sim:0.9523 - Deleting a station
# a stringed instrument often - stringed instrument , sim:0.9541 - Deleting stringed instrument
# a subway station - the subway , sim:0.9006 - Deleting a subway station
# a tape - tape , sim:0.9349 - Deleting tape
# a text - text , sim:0.9287 - Deleting text
# a trap - trap , sim:0.9391 - Deleting trap
# a two wheel vehicle - a two-wheeled vehicle, , sim:0.9475 - Deleting a two wheel vehicle
# a university - university , sim:0.9388 - Deleting university
# a wild animal - wild animal , sim:0.9529 - Deleting a wild animal
# a wind instrument - a woodwind instrument , sim:0.9318 - Deleting a woodwind instrument
# a wind instrument - an wind instrument , sim:0.9992 - Deleting an wind instrument
# a wind instrument - wind instrument , sim:0.9742 - Deleting wind instrument
# a wind instrument - woodwind instrument , sim:0.9077 - Deleting woodwind instrument
# a wooded area - a woods , sim:0.9169 - Deleting a wooded area
# a woods - the woods , sim:0.9353 - Deleting the woods
# a worm - worm , sim:0.9469 - Deleting a worm
# a zoo - the zoo , sim:0.9510 - Deleting the zoo
# actor - an actor , sim:0.9505 - Deleting actor
# an alcoholic beverage - an alcoholic drink , sim:0.9708 - Deleting an alcoholic beverage
# an elegant way to tell time - an old way of telling time , sim:0.9232 - Deleting an elegant way to tell time
# an instrument - instrument , sim:0.9631 - Deleting instrument
# an item - items , sim:0.9017 - Deleting items
# an orchestra - orchestra , sim:0.9618 - Deleting orchestra
# any garden - the garden , sim:0.9035 - Deleting any garden
# any ocean - most oceans , sim:0.9079 - Deleting most oceans
# bank - the bank , sim:0.9493 - Deleting bank
# books for learning - text books , sim:0.9001 - Deleting books for learning
# caffein - caffeine , sim:0.9475 - Deleting caffeine
# cleaning implement - household cleaning tool , sim:0.9313 - Deleting household cleaning tool
# communication system - telecommunication system , sim:0.9155 - Deleting telecommunication system
# credit - credits , sim:0.9036 - Deleting credits
# double acrostic - triple acrostic , sim:0.9498 - Deleting triple acrostic
# drunk people - drunkards , sim:0.9122 - Deleting drunkards
# feet - toes , sim:0.9179 - Deleting toes
# flat - flat thing , sim:0.9265 - Deleting flat
# garbage - some garbage , sim:0.9218 - Deleting garbage
# grass land - grassland , sim:0.9007 - Deleting grass land
# land transportation device - transportation device , sim:0.9200 - Deleting land transportation device
# liquid product - liquid solution , sim:0.9076 - Deleting liquid product
# loose shingles - shingles , sim:0.9186 - Deleting loose shingles
# nature - the nature , sim:0.9535 - Deleting the nature
# non powered device - powered device , sim:0.9437 - Deleting non powered device
# outside a house - outside of a house , sim:0.9701 - Deleting outside a house
# prepared solid food - solid food , sim:0.9031 - Deleting prepared solid food
# round - round thing , sim:0.9095 - Deleting round
# sleep - sleeping , sim:0.9208 - Deleting sleeping
# slide - sliding , sim:0.9045 - Deleting sliding
# store - the store , sim:0.9245 - Deleting the store
# street - the street , sim:0.9372 - Deleting street
# the Atlantic Ocean - the ocean , sim:0.9161 - Deleting the Atlantic Ocean
# the bathroom - washroom , sim:0.9034 - Deleting washroom
# the bedroom - your bedroom , sim:0.9061 - Deleting the bedroom
# the forest - the forest.' , sim:0.9704 - Deleting the forest.'
# the northern hemisphere - the southern hemisphere , sim:0.9339 - Deleting the northern hemisphere
# transport - transportation , sim:0.9618 - Deleting transport
# two sets of wings - two wings , sim:0.9200 - Deleting two sets of wings
# two wings - wings , sim:0.9054 - Deleting two wings
# useful - very useful , sim:0.9522 - Deleting very useful
# vegetable - vegetables , sim:0.9470 - Deleting vegetables
# woodland - woodlands , sim:0.9217 - Deleting woodland
# your home - your house , sim:0.9592 - Deleting your home
# 4382
